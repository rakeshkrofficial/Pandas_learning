# %%
import numpy as np
import pandas as pd

# %%
subs= pd.read_csv("C:\\Users\\rakes\\Documents\\Machine Learning\\CSV_file\\subs.csv").squeeze("columns")
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
vk= pd.read_csv("C:\\Users\\rakes\\Documents\\Machine Learning\\CSV_file\\kohli_ipl.csv",index_col="match_no").squeeze("columns")
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies= pd.read_csv("C:\\Users\\rakes\\Documents\\Machine Learning\\CSV_file\\bollywood.csv",index_col='movie').squeeze("columns")
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Important Series Method

# %%
# astype

import sys

sys.getsizeof(vk)
# Out:
# 3472

# %%
sk=vk.astype('int16')
sk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int16

# %%
av=sys.getsizeof(vk.astype('int16'))
av
# Out:
# 2182

# %%
sys.getsizeof(sk.astype('int8'))
# Out:
# 1967

# %%
sk.astype('int8')
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int8

# %%
# between

vk.between(50,100)
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
vk[vk.between(49,70)]
# Out:
# match_no
# 15     50
# 34     58
# 44     56
# 45     67
# 52     70
# 57     57
# 71     51
# 73     58
# 74     65
# 80     57
# 85     56
# 86     49
# 97     67
# 103    51
# 104    62
# 122    52
# 129    54
# 131    54
# 132    62
# 134    64
# 137    55
# 141    58
# 144    57
# 148    68
# 152    70
# 162    67
# 182    50
# 197    51
# 198    53
# 209    58
# Name: runs, dtype: int64

# %%
vk[vk.between(49,80)].size
# Out:
# 40

# %%
# clip

subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates

temp =pd.Series([1,1,2,3,2,4,4,5])
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    3
# 4    2
# 5    4
# 6    4
# 7    5
# dtype: int64

# %%
temp.drop_duplicates()
# Out:
# 0    1
# 2    2
# 3    3
# 5    4
# 7    5
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    3
# 4    2
# 6    4
# 7    5
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: object

# %%
# duplicated()

temp.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
temp.duplicated().sum()
# Out:
# np.int64(3)

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %% [markdown]
# Missing values

# %%
temp= pd.Series([1,2,3,np.nan,6,np.nan,7,np.nan,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     6.0
# 5     NaN
# 6     7.0
# 7     NaN
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# it counts all values
# Out:
# 10

# %%
temp.count() # it does not count null value
# Out:
# np.int64(6)

# %%
# isnull

temp.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9    False
# dtype: bool

# %%
temp.isnull().sum()
# Out:
# np.int64(4)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     6.0
# 6     7.0
# 9    10.0
# dtype: float64

# %%
# fillna

temp.fillna(0)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     0.0
# 4     6.0
# 5     0.0
# 6     7.0
# 7     0.0
# 8     0.0
# 9    10.0
# dtype: float64

# %%
temp.fillna(temp.mean())
# Out:
# 0     1.000000
# 1     2.000000
# 2     3.000000
# 3     4.833333
# 4     6.000000
# 5     4.833333
# 6     7.000000
# 7     4.833333
# 8     4.833333
# 9    10.000000
# dtype: float64

# %%
# isin

vk[(vk == 49) | (vk == 70)]
# Out:
# match_no
# 52     70
# 86     49
# 152    70
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99,70,0])]
# Out:
# match_no
# 8       0
# 52     70
# 82     99
# 86     49
# 87      0
# 91      0
# 93      0
# 130     0
# 135     0
# 152    70
# 206     0
# 207     0
# 211     0
# Name: runs, dtype: int64

# %%
# apply

movies.apply(lambda x:x.split())
# Out:
# movie
# Uri: The Surgical Strike                   [Vicky, Kaushal]
# Battalion 609                                [Vicky, Ahuja]
# The Accidental Prime Minister (film)         [Anupam, Kher]
# Why Cheat India                            [Emraan, Hashmi]
# Evening Shadows                         [Mona, Ambegaonkar]
#                                                ...
# Hum Tumhare Hain Sanam                   [Shah, Rukh, Khan]
# Aankhen (2002 film)                     [Amitabh, Bachchan]
# Saathiya (film)                             [Vivek, Oberoi]
# Company (film)                                [Ajay, Devgn]
# Awara Paagal Deewana                        [Akshay, Kumar]
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0])
# Out:
# movie
# Uri: The Surgical Strike                  Vicky
# Battalion 609                             Vicky
# The Accidental Prime Minister (film)     Anupam
# Why Cheat India                          Emraan
# Evening Shadows                            Mona
#                                          ...
# Hum Tumhare Hain Sanam                     Shah
# Aankhen (2002 film)                     Amitabh
# Saathiya (film)                           Vivek
# Company (film)                             Ajay
# Awara Paagal Deewana                     Akshay
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
subs.apply(lambda x:'Good Day' if x > subs.mean() else ' Bad Day')
# Out:
# 0       Bad Day
# 1       Bad Day
# 2       Bad Day
# 3       Bad Day
# 4       Bad Day
#          ...
# 360    Good Day
# 361    Good Day
# 362    Good Day
# 363    Good Day
# 364    Good Day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy

new = vk.head()
new
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
new[1] = 3

# %%
vk
# Out:
# match_no
# 1       3
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
