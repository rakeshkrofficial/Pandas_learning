# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Creating DataFrame

# %%
# using list
Student_data = [
    ['Rakhi','Ujjwal','Shoeb','Ravi','Raushan'],
    [96,100,99,97,77],
    [67,98,90,92,77],
    
]
pd.DataFrame(Student_data,index=['name','IQ','Marks'])
# Out:
#            0       1      2     3        4
# name   Rakhi  Ujjwal  Shoeb  Ravi  Raushan
# IQ        96     100     99    97       77
# Marks     67      98     90    92       77

# %%
students = [
    [100,80,10],
    [90,70,7],
    [120,100,14]
]

pd.DataFrame(students,columns=['Iq','marks','package'])
# Out:
#     Iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14

# %%
# Using Dictionary

student_dict= {
    
    'Iq' :[100,90,97,100,82],
    'marks': [80,70,76,0,60],
    'package' : [10,7,7,0,5]
}
student_1=pd.DataFrame(student_dict)
student_1
# Out:
#     Iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   97     76        7
# 3  100      0        0
# 4   82     60        5

# %%
# using read_csv

movies=pd.read_csv("C:\\Users\\rakes\\Documents\\Machine Learning\\CSV_file\\movies.csv")
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv("C:\\Users\\rakes\\Documents\\Machine Learning\\CSV_file\\ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # DataFrame Atrributes And Methods

# %%
# shape

print("movies =",movies.shape)
ipl.shape
# Out:
# movies = (1629, 18)
# (950, 20)

# %%
# dtype

movies.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns

movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# values

student_dict.values
# Out:
# <function dict.values()>

# %%
movies.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
# head()
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# tail()

movies.tail(4)
# Out:
#                    title_x     imdb_id  \
# 1625  Yeh Zindagi Ka Safar   tt0298607
# 1626       Sabse Bada Sukh   tt0069204
# 1627                 Daaka  tt10833860
# 1628              Humsafar   tt2403201
#
#                                             poster_path  \
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link               title_y  \
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...  Yeh Zindagi Ka Safar
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh       Sabse Bada Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka                 Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar              Humsafar
#
#             original_title  is_adult  year_of_release runtime         genres  \
# ...

# %%
# sample 

ipl.sample()
# Out:
#          ID       City        Date Season MatchNumber            Team1  \
# 852  392222  Centurion  2009-05-12   2009          42  Kings XI Punjab
#
#               Team2            Venue       TossWinner TossDecision SuperOver  \
# 852  Mumbai Indians  SuperSport Park  Kings XI Punjab          bat         N
#
#         WinningTeam    WonBy  Margin method  Player_of_Match  \
# 852  Mumbai Indians  Wickets     8.0    NaN  Harbhajan Singh
#
#                                           Team1Players  \
# 852  ['S Sohal', 'SM Katich', 'IK Pathan', 'KC Sang...
#
#                                           Team2Players    Umpire1      Umpire2
# 852  ['ST Jayasuriya', 'DJ Bravo', 'AM Rahane', 'SR...  SS Hazare  RE Koertzen

# %%
# info 

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# describe()

movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated

movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
student_1['Iq'].duplicated().sum()
# Out:
# np.int64(1)

# %%
# rename
student_1
# Out:
#     Iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   97     76        7
# 3  100      0        0
# 4   82     60        5

# %%
student_1.rename(columns={'Iq':'marks','marks':'percent','package':'LPA'}) # it is not permanent change
# Out:
#    marks  percent  LPA
# 0    100       80   10
# 1     90       70    7
# 2     97       76    7
# 3    100        0    0
# 4     82       60    5

# %%
student_1
# Out:
#     Iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   97     76        7
# 3  100      0        0
# 4   82     60        5

# %%
# for permanent change
student_1.rename(columns={'Iq':'Marks','marks':'Percent','Packege':'LPA'},inplace=True)
student_1
# Out:
#    Marks  Percent  package
# 0    100       80       10
# 1     90       70        7
# 2     97       76        7
# 3    100        0        0
# 4     82       60        5

# %% [markdown]
# # Math Methods

# %%
# sum -> axis argument

student_1.sum()
# Out:
# Marks      469
# Percent    286
# package     29
# dtype: int64

# %%
student_1.sum(axis=1)
# Out:
# 0    190
# 1    167
# 2    180
# 3    100
# 4    147
# dtype: int64

# %%
student_1.mean()
# Out:
# Marks      93.8
# Percent    57.2
# package     5.8
# dtype: float64

# %%
student_1.mean(axis=1)
# Out:
# 0    63.333333
# 1    55.666667
# 2    60.000000
# 3    33.333333
# 4    49.000000
# dtype: float64

# %%
student_1.max()
# Out:
# Marks      100
# Percent     80
# package     10
# dtype: int64

# %%
student_1.min()
# Out:
# Marks      82
# Percent     0
# package     0
# dtype: int64

# %%
student_1.median()
# Out:
# Marks      97.0
# Percent    70.0
# package     7.0
# dtype: float64

# %%
student_1.std()
# Out:
# Marks       7.758866
# Percent    32.851180
# package     3.701351
# dtype: float64

# %%
student_1.var()
# Out:
# Marks        60.2
# Percent    1079.2
# package      13.7
# dtype: float64

# %% [markdown]
# # Selecting cols from a DataFrame

# %%
# single cols

ipl['Team2']
# Out:
# 0                   Gujarat Titans
# 1                 Rajasthan Royals
# 2             Lucknow Super Giants
# 3                   Gujarat Titans
# 4                     Punjab Kings
#                   ...
# 945                Deccan Chargers
# 946    Royal Challengers Bangalore
# 947               Rajasthan Royals
# 948            Chennai Super Kings
# 949          Kolkata Knight Riders
# Name: Team2, Length: 950, dtype: object

# %%
type(ipl['Team2'])
# Out:
# pandas.core.series.Series

# %%
movies['imdb_id']
# Out:
# 0        tt8291224
# 1        tt9472208
# 2        tt6986710
# 3        tt8108208
# 4        tt6028796
#            ...
# 1624     tt0301250
# 1625     tt0298607
# 1626     tt0069204
# 1627    tt10833860
# 1628     tt2403201
# Name: imdb_id, Length: 1629, dtype: object

# %%
# multiple cols

ipl[['Team1','Team2','Venue']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue
# 0              Narendra Modi Stadium, Ahmedabad
# 1              Narendra Modi Stadium, Ahmedabad
# 2                         Eden Gardens, Kolkata
# ...

# %%
type(ipl[['Team1','Team2','Venue']])
# Out:
# pandas.core.frame.DataFrame

# %%
movies[['title_x','imdb_id']]
# Out:
#                                    title_x     imdb_id
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
# [1629 rows x 2 columns]

# %% [markdown]
# # Selecting row

# %%
student_dict= {
    'name':['Rakhi','Ujjwal','Shoeb','Ravi','Raushan'],
    'Iq' :[100,90,97,100,82],
    'marks': [80,70,76,0,60],
    'package' : [10,7,7,0,5]
}
student_1=pd.DataFrame(student_dict)
student_1.set_index('name',inplace=True)
student_1
# Out:
#           Iq  marks  package
# name
# Rakhi    100     80       10
# Ujjwal    90     70        7
# Shoeb     97     76        7
# Ravi     100      0        0
# Raushan   82     60        5

# %%
# iloc - searches using index positions
# loc - searches using index labels

# %%
# single row

movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
type(movies.iloc[5])
# Out:
# pandas.core.series.Series

# %%
# multiple row 

movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.iloc[5:16:2]
# Out:
#               title_x    imdb_id  \
# 5         Soni (film)  tt6078866
# 7          Bombairiya  tt4971258
# 9    Thackeray (film)  tt7777196
# 11          Gully Boy  tt2395469
# 13      Total Dhamaal  tt7639372
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link        title_y  \
# 5         https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 7          https://en.wikipedia.org/wiki/Bombairiya     Bombairiya
# 9    https://en.wikipedia.org/wiki/Thackeray_(film)      Thackeray
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# ...

# %%
# fancy indexing

movies.iloc[[0,4,7]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 7                Bombairiya  tt4971258
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 7           https://en.wikipedia.org/wiki/Bombairiya
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 7                Bombairiya                Bombairiya         0
#
#    year_of_release runtime              genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc

# single

student_1.loc['Shoeb']
# Out:
# Iq         97
# marks      76
# package     7
# Name: Shoeb, dtype: int64

# %%
# multiple

student_1.loc['Shoeb':'Raushan']
# Out:
#           Iq  marks  package
# name
# Shoeb     97     76        7
# Ravi     100      0        0
# Raushan   82     60        5

# %%
student_1.iloc[0:3]
# Out:
#          Iq  marks  package
# name
# Rakhi   100     80       10
# Ujjwal   90     70        7
# Shoeb    97     76        7

# %%
student_1.loc['Shoeb':'Raushan':2]
# Out:
#          Iq  marks  package
# name
# Shoeb    97     76        7
# Raushan  82     60        5

# %%
# fancy 

student_1.loc[['Ujjwal','Ravi','Rakhi']]
# Out:
#          Iq  marks  package
# name
# Ujjwal   90     70        7
# Ravi    100      0        0
# Rakhi   100     80       10

# %% [markdown]
# # Selecting both rows and cols

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.iloc[3:5,0:5]
# Out:
#            title_x    imdb_id  \
# 3  Why Cheat India  tt8108208
# 4  Evening Shadows  tt6028796
#
#                                          poster_path  \
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                        wiki_link          title_y
# 3  https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows

# %%
movies.loc[0:2,'title_x':'wiki_link']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
